# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/food_coded.csv")

# %%
df.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
# ...

# %%
df.columns
# Out:
# Index(['GPA', 'Gender', 'breakfast', 'calories_chicken', 'calories_day',
#        'calories_scone', 'coffee', 'comfort_food', 'comfort_food_reasons',
#        'comfort_food_reasons_coded', 'cook', 'comfort_food_reasons_coded.1',
#        'cuisine', 'diet_current', 'diet_current_coded', 'drink',
#        'eating_changes', 'eating_changes_coded', 'eating_changes_coded1',
#        'eating_out', 'employment', 'ethnic_food', 'exercise',
#        'father_education', 'father_profession', 'fav_cuisine',
#        'fav_cuisine_coded', 'fav_food', 'food_childhood', 'fries', 'fruit_day',
#        'grade_level', 'greek_food', 'healthy_feeling', 'healthy_meal',
#        'ideal_diet', 'ideal_diet_coded', 'income', 'indian_food',
#        'italian_food', 'life_rewarding', 'marital_status',
#        'meals_dinner_friend', 'mother_education', 'mother_profession',
#        'nutritional_check', 'on_off_campus', 'parents_cook', 'pay_meal_out',
# ...

# %%
df.describe()
# Out:
#            Gender   breakfast  calories_chicken  calories_day  calories_scone  \
# count  125.000000  125.000000        125.000000    106.000000      124.000000
# mean     1.392000    1.112000        577.320000      3.028302      505.241935
# std      0.490161    0.316636        131.214156      0.639308      230.840506
# min      1.000000    1.000000        265.000000      2.000000      315.000000
# 25%      1.000000    1.000000        430.000000      3.000000      420.000000
# 50%      1.000000    1.000000        610.000000      3.000000      420.000000
# 75%      2.000000    1.000000        720.000000      3.000000      420.000000
# max      2.000000    2.000000        720.000000      4.000000      980.000000
#
#           coffee  comfort_food_reasons_coded        cook  \
# count  125.00000                  106.000000  122.000000
# mean     1.75200                    2.698113    2.786885
# std      0.43359                    1.972042    1.038351
# ...

# %%
df.isnull().sum()
# Out:
# GPA                  2
# Gender               0
# breakfast            0
# calories_chicken     0
# calories_day        19
#                     ..
# type_sports         26
# veggies_day          0
# vitamins             0
# waffle_calories      0
# weight               2
# Length: 61, dtype: int64

# %%
df.replace(np.nan,'0',inplace=True)

# %%
df.isnull().sum()
# Out:
# GPA                 0
# Gender              0
# breakfast           0
# calories_chicken    0
# calories_day        0
#                    ..
# type_sports         0
# veggies_day         0
# vitamins            0
# waffle_calories     0
# weight              0
# Length: 61, dtype: int64

# %%
df.dtypes
# Out:
# GPA                 object
# Gender               int64
# breakfast            int64
# calories_chicken     int64
# calories_day        object
#                      ...
# type_sports         object
# veggies_day          int64
# vitamins             int64
# waffle_calories      int64
# weight              object
# Length: 61, dtype: object

# %%
df.shape
# Out:
# (125, 61)

# %%
df.drop_duplicates(inplace=True)

# %%
plt.subplot(221)
df['Gender'].value_counts().plot(kind = 'bar',title = 'Gender of people',figsize = (16,9))
plt.xticks(rotation=0)
plt.subplot(222)
df['parents_cook'].value_counts().plot(kind='bar',title = 'Students whose parents cook')
plt.xticks(rotation=0)
plt.subplot(223)
df['on_off_campus'].value_counts().plot(kind='bar',title = 'Staying on or off campus')
plt.xticks(rotation=0)
plt.subplot(224)
df['pay_meal_out'].value_counts().plot(kind = 'bar',title = 'Students who pay for their meal outside')
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, '3'),
#   Text(1, 0, '4'),
#   Text(2, 0, '2'),
#   Text(3, 0, '5'),
#   Text(4, 0, '6')])

# %%
sns.distplot(df['calories_scone'])
# Out:
# <ipython-input-14-13d2b3bf8213>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['calories_scone'])
# <Axes: xlabel='calories_scone', ylabel='Density'>

# %%
df['weight'] = pd.to_numeric(df['weight'],
                                     errors = 'coerce')

# %%
df.isnull().sum()
# Out:
# GPA                 0
# Gender              0
# breakfast           0
# calories_chicken    0
# calories_day        0
#                    ..
# type_sports         0
# veggies_day         0
# vitamins            0
# waffle_calories     0
# weight              3
# Length: 61, dtype: int64

# %%
df.replace(np.nan,'0',inplace=True)

# %%
sns.distplot(df['weight'])
# Out:
# <ipython-input-18-81c4af9784c0>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['weight'])
# <Axes: xlabel='weight', ylabel='Density'>

# %%
temp = df.sort_values(by='Gender', ascending = True)
temp
# Out:
#      GPA  Gender  breakfast  calories_chicken calories_day calories_scone  \
# 124  3.9       1          1               430            0          315.0
# 60   3.6       1          1               610          4.0          420.0
# 59   3.7       1          1               610            0          420.0
# 58   3.5       1          1               610          3.0          420.0
# 57   2.8       1          1               610          4.0          980.0
# ..   ...     ...        ...               ...          ...            ...
# 48   3.5       2          2               430            0          315.0
# 47   2.8       2          1               430            0          980.0
# 46   3.8       2          1               430          2.0          420.0
# 87   3.2       2          1               720          3.0          420.0
# 62   3.9       2          1               610          4.0          980.0
#
#      coffee                                comfort_food  \
# ...

# %%
temp[temp['Gender']==1].sort_values(by = 'GPA',ascending = True)
# Out:
#            GPA  Gender  breakfast  calories_chicken calories_day  \
# 102          0       1          1               610          4.0
# 5         2.25       1          1               610          3.0
# 85         2.6       1          1               265          3.0
# 63         2.6       1          1               610          4.0
# 33         2.8       1          1               720          3.0
# ..         ...     ...        ...               ...          ...
# 16           4       1          1               265          3.0
# 71           4       1          1               720            0
# 30           4       1          1               720          3.0
# 61   Personal        1          1               610          2.0
# 104    Unknown       1          1               720          3.0
#
#     calories_scone  coffee                                       comfort_food  \
# 102          420.0       2                  Pizza, mashed potatoes, spaghetti
# ...

# %%
temp[temp['Gender']==2].sort_values(by = 'GPA',ascending = True)
# Out:
#             GPA  Gender  breakfast  calories_chicken calories_day  \
# 15            0       2          2               430            0
# 19          2.2       2          1               430          2.0
# 0           2.4       2          1               430            0
# 74         2.71       2          2               265          2.0
# 47          2.8       2          1               430            0
# 114         2.8       2          1               610          3.0
# 111         2.9       2          1               265          2.0
# 39            3       2          1               720            0
# 27            3       2          1               610          4.0
# 123           3       2          1               720          4.0
# 77          3.1       2          2               265          2.0
# 14          3.1       2          1               610          3.0
# 72          3.1       2          2               610          3.0
# ...

# %%
sns.relplot(y='weight', x='parents_cook', hue='Gender', data=df)

# %%
df.groupby('Gender')[['parents_cook', 'pay_meal_out']].mean().T.plot(figsize=(12,8))
# Out:
# <Axes: >
